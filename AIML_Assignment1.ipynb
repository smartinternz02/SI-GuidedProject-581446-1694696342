# %%
import pandas as pd
import numpy as np
from numpy import random

# %%
r1=[random.randint(100) for _ in range(4)]
r2=[random.randint(100) for _ in range(4)]
r3=[random.randint(100) for _ in range(4)]
r4=[random.randint(100) for _ in range(4)]
df = pd.DataFrame([r1,r2,r3,r4])
print(df)
# Out:
#     0   1   2   3
# 0  62  16   1  19
# 1  43  46  47  94
# 2  55  89   4  20
# 3  99  97  95  39

# %%
df.columns=['Random Value 1','Random Value 2','Random Value 3','Random Value 4']
df
# Out:
#    Random Value 1  Random Value 2  Random Value 3  Random Value 4
# 0              62              16               1              19
# 1              43              46              47              94
# 2              55              89               4              20
# 3              99              97              95              39

# %%
df.describe()
# Out:
#        Random Value 1  Random Value 2  Random Value 3  Random Value 4
# count        4.000000        4.000000        4.000000        4.000000
# mean        64.750000       62.000000       36.750000       43.000000
# std         24.143667       37.973675       44.154086       35.223098
# min         43.000000       16.000000        1.000000       19.000000
# 25%         52.000000       38.500000        3.250000       19.750000
# 50%         58.500000       67.500000       25.500000       29.500000
# 75%         71.250000       91.000000       59.000000       52.750000
# max         99.000000       97.000000       95.000000       94.000000

# %%
df.isnull().any()
# Out:
# Random Value 1    False
# Random Value 2    False
# Random Value 3    False
# Random Value 4    False
# dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Random Value 1  4 non-null      int64
#  1   Random Value 2  4 non-null      int64
#  2   Random Value 3  4 non-null      int64
#  3   Random Value 4  4 non-null      int64
# dtypes: int64(4)
# memory usage: 256.0 bytes

# %%
df.loc[:,'Random Value 2':'Random Value 3']
# Out:
#    Random Value 2  Random Value 3
# 0              16               1
# 1              46              47
# 2              89               4
# 3              97              95

# %%
df.iloc[:,1:3]
# Out:
#    Random Value 2  Random Value 3
# 0              16               1
# 1              46              47
# 2              89               4
# 3              97              95
